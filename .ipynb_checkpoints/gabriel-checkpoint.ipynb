# %% [markdown]
# # Importing Dataset

# %%
# Insert Kaggle username and key 
import os
os.environ['KAGGLE_USERNAME'] = 'gabrielong' # username
os.environ['KAGGLE_KEY'] = "4967ce4719dde94b48812ee81d1311de" # key

# %%
# !kaggle datasets download -d clmentbisaillon/fake-and-real-news-dataset
# !unzip fake-and-real-news-dataset.zip
# Out:
# Downloading fake-and-real-news-dataset.zip to /Users/gabrielong/Documents/Y4S1/BT4222/BT4222
# 100%|██████████████████████████████████████| 41.0M/41.0M [00:05<00:00, 11.6MB/s]
# 100%|██████████████████████████████████████| 41.0M/41.0M [00:05<00:00, 7.20MB/s]
# Archive:  fake-and-real-news-dataset.zip
#   inflating: Fake.csv
#   inflating: True.csv

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis

# %%
fake_news = pd.read_csv("Fake.csv")
real_news = pd.read_csv("True.csv")

# %%
fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
real_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake_news['fake'] = 1
real_news['fake'] = 0
news = pd.concat([fake_news, real_news])

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  fake
# 0  December 31, 2017     1
# 1  December 31, 2017     1
# 2  December 30, 2017     1
# 3  December 29, 2017     1
# 4  December 25, 2017     1

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   fake     44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ MB

# %%
news.describe()
# Out:
#                fake
# count  44898.000000
# mean       0.522985
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
#Check for missing data
news.isna().value_counts()
# Out:
# title  text   subject  date   fake
# False  False  False    False  False    44898
# dtype: int64

# %%
#Check for duplicates
news['all_text'] = news['title'] + ' ' + news['text']
len(news['all_text'].unique())
# Out:
# 39105

# %%
len(news['title'].unique())
# Out:
# 38729

# %%
#Number of duplicates
len(news) - len(news['all_text'].unique())
# Out:
# 5793

# %%
news.drop_duplicates(subset=['all_text'], inplace = True)
news.shape
# Out:
# (39105, 6)

# %%
ax = sns.countplot(x='fake', data=news, palette=['g','r'])
ax.set_title('Fake Breakdown')
for i in ax.patches:
    ax.annotate(f'\n{i.get_height()}', (i.get_x() + 0.3, i.get_height()), ha='center', va='top', color='white', size=15)

# %% [markdown]
# After removing duplicates, we now have 21197 real news and 17908 fake news articles to work with.

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='subject', data=news, hue='fake', palette=['g','r'])
ax.set_title('Subject Distribution')
ax.set(ylim=(0, 14000))
for p in ax.patches:
    ax.annotate(f'\n{p.get_height().astype(int)}', (p.get_x()+0.2, p.get_height() + 1000), ha='center', va='top', color='black', size=9)

# %%
#Overall word length distribution
news['length'] = [len(x.split()) for x in news['text']]
sns.histplot(x='length', data=news, bins = 50)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
#Fake data distribution of word length
sns.histplot(x='length', data=news.loc[news['fake'] == 1], bins = 50)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
sns.histplot(x='length', data=news.loc[news['fake'] == 0], bins = 50)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
from wordcloud import WordCloud, STOPWORDS
#Word Cloud
stopwords = set(STOPWORDS)
def give_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=0
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
give_wordcloud(news,'All News')
give_wordcloud(news[news['fake'] == 1], 'Fake News')
give_wordcloud(news[news['fake'] == 0], 'Real News')

# %% [markdown]
# Fake news shows emotive and loaded language such as 'Drunk' and 'Obsessed', and biased persons such as Donald Trump are often mentioned.
# Real news shows distinguished establishments such as 'NATO'and 'Reuters', and does not contain any emotive language. Instead, the words lean more towards factual.

# %% [markdown]
# # Data Preparation

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  fake                                           all_text  \
# 0  December 31, 2017     1   Donald Trump Sends Out Embarrassing New Year’...
# 1  December 31, 2017     1   Drunk Bragging Trump Staffer Started Russian ...
# 2  December 30, 2017     1   Sheriff David Clarke Becomes An Internet Joke...
# 3  December 29, 2017     1   Trump Is So Obsessed He Even Has Obama’s Name...
# 4  December 25, 2017     1   Pope Francis Just Called Out Donald Trump Dur...
#
#    length
# 0     495
# 1     305
# 2     580
# 3     444
# 4     420

# %%
# news.drop(labels=['title','text'],axis=1,inplace=True)
# news.head()

# %%
news.shape
# Out:
# (39105, 7)

# %%
fake_news['text'][0]
# Out:
# 'Donald Trump just couldn t wish all Americans a Happy New Year and leave it at that. Instead, he had to give a shout out to his enemies, haters and  the very dishonest fake news media.  The former reality show star had just one job to do and he couldn t do it. As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year,  President Angry Pants tweeted.  2018 will be a great year for America! As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year. 2018 will be a great year for America!  Donald J. Trump (@realDonaldTrump) December 31, 2017Trump s tweet went down about as welll as you d expect.What kind of president sends a New Year s greeting like this despicable, petty, infantile gibberish? Only Trump! His lack of decency won t even allow him to rise above the gutter long enough to wish the American citizens a happy new year!  Bishop Talbert Swan (@TalbertSwan) December 31, 2017no one likes you  Calvin (@calvinstowell) December 31, 2017Your impeachment would make 2018 a great year for America, but I ll also accept regaining control of Congress.  Miranda Yaver (@mirandayaver) December 31, 2017Do you hear yourself talk? When you have to include that many people that hate you you have to wonder? Why do the they all hate me?  Alan Sandoval (@AlanSandoval13) December 31, 2017Who uses the word Haters in a New Years wish??  Marlene (@marlene399) December 31, 2017You can t just say happy new year?  Koren pollitt (@Korencarpenter) December 31, 2017Here s Trump s New Year s Eve tweet from 2016.Happy New Year to all, including to my many enemies and those who have fought me and lost so badly they just don t know what to do. Love!  Donald J. Trump (@realDonaldTrump) December 31, 2016This is nothing new for Trump. He s been doing this for years.Trump has directed messages to his  enemies  and  haters  for New Year s, Easter, Thanksgiving, and the anniversary of 9/11. pic.twitter.com/4FPAe2KypA  Daniel Dale (@ddale8) December 31, 2017Trump s holiday tweets are clearly not presidential.How long did he work at Hallmark before becoming President?  Steven Goodine (@SGoodine) December 31, 2017He s always been like this . . . the only difference is that in the last few years, his filter has been breaking down.  Roy Schulze (@thbthttt) December 31, 2017Who, apart from a teenager uses the term haters?  Wendy (@WendyWhistles) December 31, 2017he s a fucking 5 year old  Who Knows (@rainyday80) December 31, 2017So, to all the people who voted for this a hole thinking he would change once he got into power, you were wrong! 70-year-old men don t change and now he s a year older.Photo by Andrew Burton/Getty Images.'

# %%
real_news['title']
# Out:
# 0        As U.S. budget fight looms, Republicans flip t...
# 1        U.S. military to accept transgender recruits o...
# 2        Senior U.S. Republican senator: 'Let Mr. Muell...
# 3        FBI Russia probe helped by Australian diplomat...
# 4        Trump wants Postal Service to charge 'much mor...
#                                ...
# 21412    'Fully committed' NATO backs new U.S. approach...
# 21413    LexisNexis withdrew two products from Chinese ...
# 21414    Minsk cultural hub becomes haven from authorities
# 21415    Vatican upbeat on possibility of Pope Francis ...
# 21416    Indonesia to buy $1.14 billion worth of Russia...
# Name: title, Length: 21417, dtype: object

# %%
df = news.copy()

# %%
import string
import re
import nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#Functions
def count_chars(text):
    return len(text)
def count_words(text):
    return len(text.split())
def count_capital_words(text):
    return sum(map(str.isupper,text.split()))
def count_sent(text):
    return len(nltk.sent_tokenize(text))

def getPunctuations(text_col):
    '''
    Parameters
    ----------
    text_col : Series of strings
    
    Returns
    -------
    punctuations : string of all non-alphanumeric & non-space characters
    '''
    regx = re.compile(r'[\W_]')
    res = []
    for i in text_col:
        res.extend(regx.findall(i))
    res = set(res)
    spaces = ['\u200a', '\u200b', '\u200f', '\u202a', '\u200e', '\xa0', '\u202c', '\ufeff', '\n', '\r', '\t', ' ']
    for s in spaces:
        res.remove(s)
    
    punctuations = ''
    for r in res:
        punctuations += r
        
    return punctuations

def count_all_punctuations(text):
    count = 0
    for i in getPunctuations(text):
        count += 1
    return count

def count_words_in_quotes(text):
    x = re.findall(f"{string.punctuation[1]}.{string.punctuation[1]}|{string.punctuation[6]}.{string.punctuation[6]}|“.”|‘.’", text)
    count=0
    if x is None:
        return 0
    else:
        for i in x:
            t=i[1:-1]
            count+=count_words(t)
        return count
def count_unique_words(text):
    return len(set(text.split()))
def count_stopwords(text):
    stop_words = set(stopwords.words('english'))  
    word_tokens = word_tokenize(text)
    stopwords_x = [w for w in word_tokens if w in stop_words]
    return len(stopwords_x)

# %%
df['char_count'] = df["all_text"].apply(lambda x:count_chars(x))
df['word_count'] = df["all_text"].apply(lambda x:count_words(x))
df['sent_count'] = df["all_text"].apply(lambda x:count_sent(x))
df['capital_word_count'] = df["all_text"].apply(lambda x:count_capital_words(x))
df['quoted_word_count'] = df["all_text"].apply(lambda x:count_words_in_quotes(x))
df['stopword_count'] = df["all_text"].apply(lambda x:count_stopwords(x))
df['unique_word_count'] = df["all_text"].apply(lambda x:count_unique_words(x))
count = lambda l1,l2: sum([1 for x in l1 if x in l2])
df['punct_count'] = df.all_text.apply(lambda s: count(s, string.punctuation))
df['avg_wordlength'] = df['char_count']/df['word_count']
df['avg_sentlength'] = df['word_count']/df['sent_count']
df['unique_vs_words'] = df['unique_word_count']/df['word_count']
df['stopwords_vs_words'] = df['stopword_count']/df['word_count']

# %%
df.drop('length', axis=1)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  fake  \
# 0      December 31, 2017     1
# 1      December 31, 2017     1
# 2      December 30, 2017     1
# 3      December 29, 2017     1
# 4      December 25, 2017     1
# ...                  ...   ...
# 21412   August 22, 2017      0
# 21413   August 22, 2017      0
# 21414   August 22, 2017      0
# 21415   August 22, 2017      0
# 21416   August 22, 2017      0
#
#                                                 all_text  char_count  \
# 0       Donald Trump Sends Out Embarrassing New Year’...        2973
# 1       Drunk Bragging Trump Staffer Started Russian ...        1968
# 2       Sheriff David Clarke Becomes An Internet Joke...        3688
# 3       Trump Is So Obsessed He Even Has Obama’s Name...        2853
# 4       Pope Francis Just Called Out Donald Trump Dur...        2417
# ...                                                  ...         ...
# 21412  'Fully committed' NATO backs new U.S. approach...        2883
# 21413  LexisNexis withdrew two products from Chinese ...         853
# 21414  Minsk cultural hub becomes haven from authorit...        2000
# 21415  Vatican upbeat on possibility of Pope Francis ...        1261
# 21416  Indonesia to buy $1.14 billion worth of Russia...        1391
#
#        word_count  sent_count  capital_word_count  quoted_word_count  \
# 0             507          28                   5                  0
# 1             313          11                   3                  0
# 2             595          25                  42                  0
# 3             458          15                   6                  0
# 4             431          19                   0                  0
# ...           ...         ...                 ...                ...
# 21412         475          15                  17                  0
# 21413         132           6                   1                  0
# 21414         327          16                   5                  0
# 21415         214           8                   1                  0
# 21416         219           9                   3                  0
#
#        stopword_count  unique_word_count  punct_count  avg_wordlength  \
# 0                 195                282          122        5.863905
# 1                 120                209           39        6.287540
# 2                 220                344          148        6.198319
# 3                 164                278          120        6.229258
# 4                 197                244           40        5.607889
# ...               ...                ...          ...             ...
# 21412             183                272           75        6.069474
# 21413              46                 84           18        6.462121
# 21414             133                221           48        6.116208
# 21415              83                145           21        5.892523
# 21416              68                148           32        6.351598
#
#        avg_sentlength  unique_vs_words  stopwords_vs_words
# 0           18.107143         0.556213            0.384615
# 1           28.454545         0.667732            0.383387
# 2           23.800000         0.578151            0.369748
# 3           30.533333         0.606987            0.358079
# 4           22.684211         0.566125            0.457077
# ...               ...              ...                 ...
# 21412       31.666667         0.572632            0.385263
# 21413       22.000000         0.636364            0.348485
# 21414       20.437500         0.675841            0.406728
# 21415       26.750000         0.677570            0.387850
# 21416       24.333333         0.675799            0.310502
#
# [39105 rows x 18 columns]

# %%
lowercased = [t.lower() for t in df['all_text']]

# %%
tokens = [nltk.word_tokenize(i) for i in lowercased]

# %%
tags = [nltk.pos_tag(i) for i in tokens]

# %%
from collections import Counter
counts = [Counter(tag for word, tag in i) for i in tags]

# %%
#NN is noun, RB is adverb
nouns_count = [i['NN'] for i in counts]
adverb_count = [i['RB'] for i in counts]

# %%
df['noun_count'] = nouns_count
df['adverb_count'] = adverb_count

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  fake                                           all_text  \
# 0  December 31, 2017     1   Donald Trump Sends Out Embarrassing New Year’...
# 1  December 31, 2017     1   Drunk Bragging Trump Staffer Started Russian ...
# 2  December 30, 2017     1   Sheriff David Clarke Becomes An Internet Joke...
# 3  December 29, 2017     1   Trump Is So Obsessed He Even Has Obama’s Name...
# 4  December 25, 2017     1   Pope Francis Just Called Out Donald Trump Dur...
#
#    length  char_count  word_count  sent_count  ...  quoted_word_count  \
# 0     495        2973         507          28  ...                  0
# 1     305        1968         313          11  ...                  0
# 2     580        3688         595          25  ...                  0
# 3     444        2853         458          15  ...                  0
# 4     420        2417         431          19  ...                  0
#
#    stopword_count  unique_word_count  punct_count  avg_wordlength  \
# 0             195                282          122        5.863905
# 1             120                209           39        6.287540
# 2             220                344          148        6.198319
# 3             164                278          120        6.229258
# 4             197                244           40        5.607889
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words  noun_count  \
# 0       18.107143         0.556213            0.384615         116
# 1       28.454545         0.667732            0.383387          94
# 2       23.800000         0.578151            0.369748         167
# 3       30.533333         0.606987            0.358079         143
# 4       22.684211         0.566125            0.457077          79
#
#    adverb_count
# 0            36
# 1            10
# 2            20
# 3            24
# 4            16
#
# [5 rows x 21 columns]

# %%
df.iloc[:,6:]
# Out:
#        length  char_count  word_count  sent_count  capital_word_count  \
# 0         495        2973         507          28                   5
# 1         305        1968         313          11                   3
# 2         580        3688         595          25                  42
# 3         444        2853         458          15                   6
# 4         420        2417         431          19                   0
# ...       ...         ...         ...         ...                 ...
# 21412     466        2883         475          15                  17
# 21413     125         853         132           6                   1
# 21414     320        2000         327          16                   5
# 21415     205        1261         214           8                   1
# 21416     210        1391         219           9                   3
#
#        quoted_word_count  stopword_count  unique_word_count  punct_count  \
# 0                      0             195                282          122
# 1                      0             120                209           39
# 2                      0             220                344          148
# 3                      0             164                278          120
# 4                      0             197                244           40
# ...                  ...             ...                ...          ...
# 21412                  0             183                272           75
# 21413                  0              46                 84           18
# 21414                  0             133                221           48
# 21415                  0              83                145           21
# 21416                  0              68                148           32
#
#        avg_wordlength  avg_sentlength  unique_vs_words  stopwords_vs_words  \
# 0            5.863905       18.107143         0.556213            0.384615
# 1            6.287540       28.454545         0.667732            0.383387
# 2            6.198319       23.800000         0.578151            0.369748
# 3            6.229258       30.533333         0.606987            0.358079
# 4            5.607889       22.684211         0.566125            0.457077
# ...               ...             ...              ...                 ...
# 21412        6.069474       31.666667         0.572632            0.385263
# 21413        6.462121       22.000000         0.636364            0.348485
# 21414        6.116208       20.437500         0.675841            0.406728
# 21415        5.892523       26.750000         0.677570            0.387850
# 21416        6.351598       24.333333         0.675799            0.310502
#
#        noun_count  adverb_count
# 0             116            36
# 1              94            10
# 2             167            20
# 3             143            24
# 4              79            16
# ...           ...           ...
# 21412         100            18
# 21413          37             1
# 21414          74            15
# 21415          54             8
# 21416          62             6
#
# [39105 rows x 15 columns]

# %%
df2 = df[['title','subject']]
df2.head()
# Out:
#                                                title subject
# 0   Donald Trump Sends Out Embarrassing New Year’...    News
# 1   Drunk Bragging Trump Staffer Started Russian ...    News
# 2   Sheriff David Clarke Becomes An Internet Joke...    News
# 3   Trump Is So Obsessed He Even Has Obama’s Name...    News
# 4   Pope Francis Just Called Out Donald Trump Dur...    News

# %%
df2['char_count'] = df2["title"].apply(lambda x:count_chars(x))
df2['word_count'] = df2["title"].apply(lambda x:count_words(x))
df2['sent_count'] = df2["title"].apply(lambda x:count_sent(x))
df2['capital_word_count'] = df2["title"].apply(lambda x:count_capital_words(x))
df2['quoted_word_count'] = df2["title"].apply(lambda x:count_words_in_quotes(x))
df2['stopword_count'] = df2["title"].apply(lambda x:count_stopwords(x))
df2['unique_word_count'] = df2["title"].apply(lambda x:count_unique_words(x))
count = lambda l1,l2: sum([1 for x in l1 if x in l2])
df2['punct_count'] = df2.title.apply(lambda s: count(s, string.punctuation))
df2['avg_wordlength'] = df2['char_count']/df2['word_count']
df2['avg_sentlength'] = df2['word_count']/df2['sent_count']
df2['unique_vs_words'] = df2['unique_word_count']/df2['word_count']
df2['stopwords_vs_words'] = df2['stopword_count']/df2['word_count']
df2.head()
# Out:
# <ipython-input-42-71392e19c1d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['char_count'] = df2["title"].apply(lambda x:count_chars(x))
# <ipython-input-42-71392e19c1d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['word_count'] = df2["title"].apply(lambda x:count_words(x))
# <ipython-input-42-71392e19c1d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['sent_count'] = df2["title"].apply(lambda x:count_sent(x))
# <ipython-input-42-71392e19c1d2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['capital_word_count'] = df2["title"].apply(lambda x:count_capital_words(x))
# <ipython-input-42-71392e19c1d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['quoted_word_count'] = df2["title"].apply(lambda x:count_words_in_quotes(x))
# <ipython-input-42-71392e19c1d2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['stopword_count'] = df2["title"].apply(lambda x:count_stopwords(x))
# <ipython-input-42-71392e19c1d2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['unique_word_count'] = df2["title"].apply(lambda x:count_unique_words(x))
# <ipython-input-42-71392e19c1d2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['punct_count'] = df2.title.apply(lambda s: count(s, string.punctuation))
# <ipython-input-42-71392e19c1d2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['avg_wordlength'] = df2['char_count']/df2['word_count']
# <ipython-input-42-71392e19c1d2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['avg_sentlength'] = df2['word_count']/df2['sent_count']
# <ipython-input-42-71392e19c1d2>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['unique_vs_words'] = df2['unique_word_count']/df2['word_count']
# <ipython-input-42-71392e19c1d2>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['stopwords_vs_words'] = df2['stopword_count']/df2['word_count']
#                                                title subject  char_count  \
# 0   Donald Trump Sends Out Embarrassing New Year’...    News          79
# 1   Drunk Bragging Trump Staffer Started Russian ...    News          69
# 2   Sheriff David Clarke Becomes An Internet Joke...    News          90
# 3   Trump Is So Obsessed He Even Has Obama’s Name...    News          78
# 4   Pope Francis Just Called Out Donald Trump Dur...    News          70
#
#    word_count  sent_count  capital_word_count  quoted_word_count  \
# 0          12           1                   0                  0
# 1           8           1                   0                  0
# 2          15           1                   0                  0
# 3          14           1                   1                  0
# 4          11           1                   0                  0
#
#    stopword_count  unique_word_count  punct_count  avg_wordlength  \
# 0               2                 12            1        6.583333
# 1               0                  8            0        8.625000
# 2               0                 15            0        6.000000
# 3               1                 14            2        5.571429
# 4               0                 11            0        6.363636
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words
# 0            12.0              1.0            0.166667
# 1             8.0              1.0            0.000000
# 2            15.0              1.0            0.000000
# 3            14.0              1.0            0.071429
# 4            11.0              1.0            0.000000

# %%
from collections import Counter
lowercased2 = [t.lower() for t in df2['title']]
tokens2 = [nltk.word_tokenize(i) for i in lowercased2]
tags2 = [nltk.pos_tag(i) for i in tokens2]
counts2 = [Counter(tag for word, tag in i) for i in tags2]
#N is noun, RB is adverb
nouns_count2 = [i['NN'] for i in counts2]
adverb_count2 = [i['RB'] for i in counts2]

# %%
df2['noun_count'] = nouns_count2
df2['adverb_count'] = adverb_count2
# Out:
# <ipython-input-44-4758ec8b40b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['noun_count'] = nouns_count2
# <ipython-input-44-4758ec8b40b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['adverb_count'] = adverb_count2

# %%
df = df.drop('length',axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.iloc[:,6:])
scaled = scaler.fit_transform(df.iloc[:,6:])
scaled_df = pd.DataFrame(scaled, columns=df.iloc[:,6:].columns)
print(scaled_df)
# Out:
#        char_count  word_count  sent_count  capital_word_count  \
# 0        0.240297    0.306265    1.084224           -0.398389
# 1       -0.276698   -0.309289   -0.331805           -0.601504
# 2        0.608109    0.585485    0.834337            3.359237
# 3        0.178566    0.150790    0.001378           -0.296832
# 4       -0.045722    0.065120    0.334562           -0.906177
# ...           ...         ...         ...                 ...
# 39100    0.193999    0.204730    0.001378            0.820300
# 39101   -0.850280   -0.883594   -0.748285           -0.804619
# 39102   -0.260237   -0.264868    0.084674           -0.398389
# 39103   -0.640395   -0.623412   -0.581693           -0.804619
# 39104   -0.573520   -0.607547   -0.498397           -0.601504
#
#        quoted_word_count  stopword_count  unique_word_count  punct_count  \
# 0              -0.034479        0.275527           0.296494     1.042602
# 1              -0.034479       -0.312486          -0.205702    -0.267709
# 2              -0.034479        0.471531           0.723017     1.453061
# 3              -0.034479        0.032482           0.268976     1.011028
# 4              -0.034479        0.291207           0.035077    -0.251922
# ...                  ...             ...                ...          ...
# 39100          -0.034479        0.181445           0.227700     0.300619
# 39101          -0.034479       -0.892658          -1.065628    -0.599233
# 39102          -0.034479       -0.210563          -0.123150    -0.125627
# 39103          -0.034479       -0.602572          -0.645984    -0.551873
# 39104          -0.034479       -0.720174          -0.625346    -0.378217
#
#        avg_wordlength  avg_sentlength  unique_vs_words  stopwords_vs_words  \
# 0           -0.226087       -0.989229        -0.793036            0.172169
# 1            0.113219       -0.117422         0.333157            0.152893
# 2            0.041759       -0.509584        -0.571489           -0.061053
# 3            0.066538        0.057724        -0.280286           -0.244106
# 4           -0.431140       -0.603594        -0.692935            1.308846
# ...               ...             ...              ...                 ...
# 39100       -0.061439        0.153212        -0.627230            0.182330
# 39101        0.253048       -0.661241         0.016381           -0.394601
# 39102       -0.024008       -0.792888         0.415051            0.519040
# 39103       -0.203165       -0.261036         0.432513            0.222917
# 39104        0.164525       -0.464649         0.414628           -0.990422
#
#        noun_count  adverb_count
# 0        0.212433      1.435445
# 1       -0.073870     -0.362714
# 2        0.876135      0.328885
# 3        0.563805      0.605525
# 4       -0.269076      0.052245
# ...           ...           ...
# 39100    0.004213      0.190565
# 39101   -0.815654     -0.985154
# 39102   -0.334145     -0.016915
# 39103   -0.594420     -0.501034
# 39104   -0.490310     -0.639354
#
# [39105 rows x 14 columns]

# %%
features = scaled_df
target = df['fake']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1)

# %%
from pandas import read_csv
from matplotlib import pyplot
from sklearn.linear_model import LogisticRegression

# feature extraction
lr_clf = LogisticRegression(random_state=1)
lr_clf.fit(X_train, y_train)
train_predicted = lr_clf.predict(X_train)
test_predicted = lr_clf.predict(X_test)

# %%
from sklearn import metrics
#Logistic Regression - Training Set
print('Logistic Regression - Training Set')
print('Accuracy')
print(metrics.accuracy_score(y_train, train_predicted))
print('Precision')
print(metrics.precision_score(y_train, train_predicted))
print('Recall')
print(metrics.precision_score(y_train, train_predicted))
print('ROC_AUC')
y_pred_prob_train = lr_clf.predict_proba(X_train)[:,1]
print(metrics.roc_auc_score(y_train, y_pred_prob_train))
print('Confusion Matrix')
confusion = metrics.confusion_matrix(y_train, train_predicted)
print(confusion)
# Out:
# Logistic Regression - Training Set
# Accuracy
# 0.8378000545553737
# Precision
# 0.8430720506730008
# Recall
# 0.8430720506730008
# ROC_AUC
# 0.9031272972816439
# Confusion Matrix
# [[13923  1982]
#  [ 2775 10648]]

# %%
#Logistic Regression - Test Set
print('Logistic Regression - Test Set')
print('Accuracy')
print(metrics.accuracy_score(y_test, test_predicted))
print('Precision')
print(metrics.precision_score(y_test, test_predicted))
print('Recall')
print(metrics.precision_score(y_test, test_predicted))
print('ROC_AUC')
y_pred_prob = lr_clf.predict_proba(X_test)[:,1]
print(metrics.roc_auc_score(y_test, y_pred_prob))
print('Confusion Matrix')
confusion = metrics.confusion_matrix(y_test, test_predicted)
print(confusion)
# Out:
# Logistic Regression - Test Set
# Accuracy
# 0.844430806996011
# Precision
# 0.8462616822429907
# Recall
# 0.8462616822429907
# ROC_AUC
# 0.9099455141898207
# Confusion Matrix
# [[4634  658]
#  [ 863 3622]]

# %%
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: -7.55168
# Feature: 1, Score: -2.73099
# Feature: 2, Score: -2.32114
# Feature: 3, Score: 1.19301
# Feature: 4, Score: 0.02574
# Feature: 5, Score: 5.78143
# Feature: 6, Score: 3.57385
# Feature: 7, Score: 2.02347
# Feature: 8, Score: 0.04029
# Feature: 9, Score: 0.03204
# Feature: 10, Score: 0.83551
# Feature: 11, Score: -0.06398
# Feature: 12, Score: -0.53845
# Feature: 13, Score: 3.04216

# %% [markdown]
# The more important indicators are length, word count, quoted word count.
# Some important indicators are char_count, sentence count, stopword count, adverb count.

# %%
#Without normalizing
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,6:], target, random_state=1)

# %%
# feature extraction
lr_clf = LogisticRegression(random_state=1)
lr_clf.fit(X_train, y_train)
train_predicted = lr_clf.predict(X_train)
test_predicted = lr_clf.predict(X_test)
lr_clf.score(X_test, y_test)
# Out:
# /Users/gabrielong/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8215198936279022

# %%
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB().fit(X_train, y_train)
print(nb_clf.score(X_train, y_train), nb_clf.score(X_test, y_test))
# Out:
# 0.8006342062193126 0.8106781221233508

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=1)
rf_clf.fit(X_train, y_train)
print(rf_clf.score(X_train, y_train), rf_clf.score(X_test, y_test))
# Out:
# 1.0 0.8965940472537588

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)
print(xgb_clf.score(X_train, y_train), xgb_clf.score(X_test, y_test))
# Out:
# 0.9469789961811238 0.9011966861000307

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf', gamma='scale', random_state=42)
svc.fit(X_train, y_train)
print(svc.score(X_train, y_train), svc.score(X_test, y_test))
# Out:
# 0.7458060556464812 0.7516620640278204

# %%
#Normalizing
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# feature extraction
lr_clf = LogisticRegression(random_state=1)
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.7988135419862944

# %%
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB().fit(X_train, y_train)
print(nb_clf.score(X_train, y_train), nb_clf.score(X_test, y_test))
# Out:
# 0.5454514457174031 0.5449524393985885

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)
print(xgb_clf.score(X_train, y_train), xgb_clf.score(X_test, y_test))
# Out:
# 0.9469789961811238 0.9011966861000307

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=1)
rf_clf.fit(X_train, y_train)
print(rf_clf.score(X_train, y_train), rf_clf.score(X_test, y_test))
# Out:
# 1.0 0.8964917663905083
